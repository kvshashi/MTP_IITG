# %%
#importing the libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import skimage
from skimage import io, transform
from tensorflow import keras
from keras import layers
from sklearn.model_selection import train_test_split
from keras import Model

# %%
#Importing the images
Image_path = 'D:\MTP_P1\W10\Trial_2D_TopDeep\Excel_data\img'
coll = skimage.io.ImageCollection(Image_path + '/*.png') 

#coll has the images as they are in the directory i.e is sorted order, also name of files can be viewed as coll.files[0] , shape as col[0].shape
width = 120
length = 120
# Now we will resize the image into 50*100 (width*length) , for that first we make a list as assignment is not allowed in ImageCollection, then push list itemps to a numpy array of required size
img_list = []
for i in range(len(coll)):
    img = transform.resize(coll[i], output_shape=(width,length))
    img_list.append(img)

img_arr = np.empty((120,width,length,3)) #initializes an empty numpy array which will contain 120 entries, each entry will be a 3 stacked matrices.
for i in range(120):
    img_arr[i] = np.asarray(img_list[i])

# %%
#visualizing the images
fig = plt.figure(figsize=(7, 7))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = img_arr[i]
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#now corresponding to each image we need an input tensor of size 50*100*3, matrices will contain volumefrac, fy , fx
top_set = np.empty((120,width,length,3))
#now we import our excel sheet which will provide the values with which we will populate our matrices
set_data = pd.read_excel("Top_setting.xlsx").values # .values will remove the headers i.e name of the columns

#updating the top_set to create our input with shape 120*50*100*3

for i in range(top_set.shape[0]):
    for j in range(top_set.shape[1]):
        for k in range(top_set.shape[2]):
            for l in range(top_set.shape[3]):
                top_set[i][j][k][l] = set_data[i][l]

# Now we have our input and outputs:
# input = top_set : shape - (120, 100, 100, 3)
# output = img_arr : shape - (120, 100, 100, 3)

# %%
#Now building The ANN_AutoEncoder Model

# %%
X_train, X_test, y_train, y_test = train_test_split( top_set, img_arr, test_size=0.2, random_state=0)
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
#Initializing ANN
inputs = keras.Input(shape=(width,length,3),)

x = layers.Conv2D(32, 3, activation='relu',strides = 2, padding='same')(inputs)
x = layers.Conv2D(64, 3, activation='relu',strides = 2, padding ='same')(x)
# x = layers.Conv2D(90, 3, activation='relu',strides = 1, padding ='same')(x)


conv_shape = keras.backend.int_shape(x)

x = layers.Flatten()(x)
x = layers.Dense(100, activation ='relu')(x)


x = layers.Dense(conv_shape[1]*conv_shape[2]*conv_shape[3], activation='relu')(x)
x = layers.Reshape((conv_shape[1],conv_shape[2],conv_shape[3]))(x)

# x = layers.Conv2DTranspose(90, 3, activation='relu',strides = 1, padding ='same')(x)
x = layers.Conv2DTranspose(64, 3, activation = 'relu' , strides = 2, padding = 'same')(x)
x = layers.Conv2DTranspose(32, 3, activation = 'relu' , strides = 2, padding = 'same')(x)

decoder_outputs = layers.Conv2DTranspose(3, 3, activation = 'sigmoid', padding = 'same')(x)

EncDeco = keras.Model(inputs, decoder_outputs, name='EncDeco')
EncDeco.summary()
# Out:
# Model: "EncDeco"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 120, 3)]     0
#
#  conv2d (Conv2D)             (None, 60, 60, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)        18496
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 100)               5760100
#
#  dense_1 (Dense)             (None, 57600)             5817600
#
#  reshape (Reshape)           (None, 30, 30, 64)        0
#
#  conv2d_transpose (Conv2DTra  (None, 60, 60, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 120, 120, 32)     18464
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 120, 120, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 11,653,351
# Trainable params: 11,653,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
# EncDeco.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=1e-2,
#     decay_steps=10000,
#     decay_rate=0.9)
# opt = keras.optimizers.SGD(learning_rate=lr_schedule)
# model.compile(loss='binary_crossentropy', optimizer=opt)
opt = keras.optimizers.Adam(learning_rate=0.001)
EncDeco.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
history = EncDeco.fit(X_train, y_train, batch_size = 15, epochs = 30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 7/7 [==============================] - 9s 905ms/step - loss: 0.6890 - accuracy: 0.8359 - val_loss: 0.6799 - val_accuracy: 0.9861
# Epoch 2/30
# 7/7 [==============================] - 2s 232ms/step - loss: 0.6511 - accuracy: 0.8915 - val_loss: 0.4258 - val_accuracy: 0.7726
# Epoch 3/30
# 7/7 [==============================] - 2s 229ms/step - loss: 0.2671 - accuracy: 0.7896 - val_loss: 0.1903 - val_accuracy: 0.6345
# Epoch 4/30
# 7/7 [==============================] - 2s 221ms/step - loss: 0.1767 - accuracy: 0.4448 - val_loss: 0.1709 - val_accuracy: 0.2807
# Epoch 5/30
# 7/7 [==============================] - 2s 228ms/step - loss: 0.1658 - accuracy: 0.2786 - val_loss: 0.1617 - val_accuracy: 0.2909
# Epoch 6/30
# 7/7 [==============================] - 2s 216ms/step - loss: 0.1527 - accuracy: 0.2910 - val_loss: 0.1444 - val_accuracy: 0.3010
# Epoch 7/30
# 7/7 [==============================] - 2s 223ms/step - loss: 0.1389 - accuracy: 0.3093 - val_loss: 0.1348 - val_accuracy: 0.3143
# Epoch 8/30
# 7/7 [==============================] - 1s 209ms/step - loss: 0.1319 - accuracy: 0.3201 - val_loss: 0.1319 - val_accuracy: 0.3307
# Epoch 9/30
# 7/7 [==============================] - 2s 227ms/step - loss: 0.1296 - accuracy: 0.3547 - val_loss: 0.1296 - val_accuracy: 0.3985
# Epoch 10/30
# 7/7 [==============================] - 2s 226ms/step - loss: 0.1286 - accuracy: 0.4213 - val_loss: 0.1289 - val_accuracy: 0.4433
# Epoch 11/30
# 7/7 [==============================] - 2s 219ms/step - loss: 0.1276 - accuracy: 0.4408 - val_loss: 0.1287 - val_accuracy: 0.4385
# Epoch 12/30
# 7/7 [==============================] - 1s 215ms/step - loss: 0.1274 - accuracy: 0.4422 - val_loss: 0.1287 - val_accuracy: 0.4371
# Epoch 13/30
# 7/7 [==============================] - 1s 211ms/step - loss: 0.1275 - accuracy: 0.4214 - val_loss: 0.1280 - val_accuracy: 0.4204
# Epoch 14/30
# 7/7 [==============================] - 2s 234ms/step - loss: 0.1267 - accuracy: 0.4283 - val_loss: 0.1283 - val_accuracy: 0.4337
# Epoch 15/30
# 7/7 [==============================] - 2s 222ms/step - loss: 0.1266 - accuracy: 0.4307 - val_loss: 0.1278 - val_accuracy: 0.4285
# Epoch 16/30
# 7/7 [==============================] - 2s 217ms/step - loss: 0.1265 - accuracy: 0.4323 - val_loss: 0.1277 - val_accuracy: 0.4302
# Epoch 17/30
# 7/7 [==============================] - 1s 212ms/step - loss: 0.1267 - accuracy: 0.4248 - val_loss: 0.1274 - val_accuracy: 0.4260
# Epoch 18/30
# 7/7 [==============================] - 2s 227ms/step - loss: 0.1264 - accuracy: 0.4269 - val_loss: 0.1273 - val_accuracy: 0.4229
# Epoch 19/30
# 7/7 [==============================] - 2s 226ms/step - loss: 0.1259 - accuracy: 0.4202 - val_loss: 0.1264 - val_accuracy: 0.4172
# Epoch 20/30
# 7/7 [==============================] - 2s 240ms/step - loss: 0.1255 - accuracy: 0.4183 - val_loss: 0.1258 - val_accuracy: 0.4165
# Epoch 21/30
# 7/7 [==============================] - 2s 232ms/step - loss: 0.1242 - accuracy: 0.4176 - val_loss: 0.1249 - val_accuracy: 0.4205
# Epoch 22/30
# 7/7 [==============================] - 2s 231ms/step - loss: 0.1229 - accuracy: 0.4237 - val_loss: 0.1229 - val_accuracy: 0.4212
# Epoch 23/30
# 7/7 [==============================] - 2s 231ms/step - loss: 0.1214 - accuracy: 0.4274 - val_loss: 0.1205 - val_accuracy: 0.4308
# Epoch 24/30
# 7/7 [==============================] - 2s 224ms/step - loss: 0.1170 - accuracy: 0.4344 - val_loss: 0.1162 - val_accuracy: 0.4322
# Epoch 25/30
# 7/7 [==============================] - 1s 215ms/step - loss: 0.1111 - accuracy: 0.4355 - val_loss: 0.1139 - val_accuracy: 0.4373
# Epoch 26/30
# 7/7 [==============================] - 2s 217ms/step - loss: 0.1063 - accuracy: 0.4447 - val_loss: 0.1054 - val_accuracy: 0.4462
# Epoch 27/30
# 7/7 [==============================] - 1s 214ms/step - loss: 0.1006 - accuracy: 0.4464 - val_loss: 0.1013 - val_accuracy: 0.4358
# Epoch 28/30
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0966 - accuracy: 0.4444 - val_loss: 0.0986 - val_accuracy: 0.4650
# Epoch 29/30
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0950 - accuracy: 0.4559 - val_loss: 0.0964 - val_accuracy: 0.4347
# Epoch 30/30
# 7/7 [==============================] - 1s 210ms/step - loss: 0.0925 - accuracy: 0.4405 - val_loss: 0.0916 - val_accuracy: 0.4237

# %%
fig2 = plt.figure(figsize=(10, 10))
columns = 4
rows = 3
for i in range(1, columns*rows +1):
    img =EncDeco.predict(X_test)
    fig2.add_subplot(rows, columns, i)
    plt.imshow(img[i-1])
plt.show()


fig1 = plt.figure(figsize=(10, 10))
columns = 4
rows = 3
for i in range(1, columns*rows +1):
    img = y_test[i-1]
    fig1.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 136ms/step

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,31)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
epochs = range(1,31)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
type(history.history)
# Out:
# dict

# %%
import xlsxwriter
 
workbook = xlsxwriter.Workbook('OutPut_ANN.xlsx')
worksheet = workbook.add_worksheet()
 
# Start from the first cell.
# Rows and columns are zero indexed.
row = 0
column = 0
 
content = history.history.get('val_loss')
 
# iterating through content list
for item in content :
 
    # write operation perform
    worksheet.write(row, column, item)
 
    # incrementing the value of row by one
    # with each iterations.
    row += 1
     
workbook.close()
